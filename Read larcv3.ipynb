# %%
from larcv import larcv

import pandas
import glob
import argparse
import numpy
import numpy as np

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import multivariate_normal


import draw_tools

# %matplotlib inline
# %matplotlib notebook

# %%
file_name = '/Users/deltutto/Desktop/NEXT/next_new_classification_train.h5'
next_new_meta = larcv.ImageMeta3D()
# set_dimension(size_t axis, double image_size, size_t number_of_voxels, double origin = 0);

next_new_meta.set_dimension(0, 450, 450, -225)
next_new_meta.set_dimension(1, 450, 450, -225)
next_new_meta.set_dimension(2, 550, 550, 0)

position = larcv.VectorOfDouble()
# position = next_new_meta.position(47217678)
# print next_new_meta.position(47217678, 0)
position = larcv.VectorOfDouble()
position.resize(3)
position[0] = 23
position[1] = 44
position[2] = 98
print next_new_meta.position_to_index(position)
print next_new_meta.position(61528048, 0)
print next_new_meta.position(61528048, 1)
print next_new_meta.position(61528048, 2)
# Out:
# 61528048
# 23.5
# 44.5
# 98.5

# %%
event = 0

_dx = 10
_dy = 10
_dz = 2

# %%
df_voxels = pandas.read_hdf(file_name, 'Data/sparse3d_voxels_group/voxels')
df_voxel_extents = pandas.read_hdf(file_name, 'Data/sparse3d_voxels_group/voxel_extents')

first = df_voxel_extents['first'][event]
last = first + df_voxel_extents['N'][event]
print first, last
# print df_voxel_extents

df_sub = df_voxels[first:last]
# print df_sub
print len(df_sub)

xpos = np.random.rand(len(df_sub))
ypos = np.random.rand(len(df_sub))
zpos = np.random.rand(len(df_sub))
e = np.random.rand(len(df_sub))
dx = np.random.rand(len(df_sub))
dy = np.random.rand(len(df_sub))
dz = np.random.rand(len(df_sub))

count = 0

for index, row in df_sub.iterrows():
#     print row.id, row.value
#     print next_new_meta.position(int(row.id), 0), next_new_meta.position(int(row.id), 1), next_new_meta.position(int(row.id), 2), row.value
    xpos[count] = next_new_meta.position(int(row.id), 0)
    ypos[count] = next_new_meta.position(int(row.id), 1)
    zpos[count] = next_new_meta.position(int(row.id), 2)
    
    e[count] = row.value
    
    dx[count] = 10
    dy[count] = 10
    dz[count] = 3
    
    count = count + 1
    
draw_tools.draw(xpos, ypos, zpos, dx, dy, dz, e)
# Out:
# 0 421
# 421
# ('Length', 421)
# <img src="data:image/png;base64,..." width="640">
